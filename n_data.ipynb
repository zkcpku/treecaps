# %%
from preprocess import *
# Out:
# Using backend: pytorch

# %%
datapath
# Out:
# '/home/zhangkechi/workspace/data/codenet/Project_CodeNet_Java250_spts/'

# %%
trainset, devset, testset, token_vocabsize, type_vocabsize = get_spt_dataset()
# Out:
# 75000 75000 75000
# 25374640
# 25449640
# 25449640
# 25449640
# 75000
# 45000 15000 15000
# 115 107

# %%
trainset[0]
# Out:
# [{'graph': Graph(num_nodes=171, num_edges=170,
#         ndata_schemes={'token': Scheme(shape=(), dtype=torch.int64), 'type': Scheme(shape=(), dtype=torch.int64), 'depth': Scheme(shape=(), dtype=torch.int64), 'dfs': Scheme(shape=(), dtype=torch.int64)}
#         edata_schemes={}),
#   'edge': [[0, 1],
#    [0, 2],
#    [0, 3],
#    [0, 4],
#    [1, 5],
#    [1, 6],
#    [1, 7],
#    [2, 8],
#    [2, 9],
#    [2, 10],
#    [3, 11],
#    [3, 12],
#    [6, 13],
#    [6, 14],
#    [6, 15],
#    [6, 16],
#    [6, 17],
#    [9, 18],
#    [9, 19],
#    [9, 20],
#    [9, 21],
#    [9, 22],
#    [12, 23],
#    [12, 24],
#    [12, 25],
#    [25, 26],
#    [25, 27],
#    [25, 28],
#    [27, 29],
#    [27, 30],
#    [27, 31],
#    [31, 32],
#    [31, 33],
#    [31, 34],
#    [31, 35],
#    [34, 36],
#    [34, 37],
#    [34, 38],
#    [35, 39],
#    [35, 40],
#    [35, 41],
#    [35, 42],
#    [35, 43],
#    [35, 44],
#    [35, 45],
#    [37, 46],
#    [37, 47],
#    [40, 48],
#    [40, 49],
#    [41, 50],
#    [41, 51],
#    [42, 52],
#    [42, 53],
#    [42, 54],
#    [42, 55],
#    [42, 56],
#    [43, 57],
#    [43, 58],
#    [44, 59],
#    [44, 60],
#    [44, 61],
#    [44, 62],
#    [44, 63],
#    [46, 64],
#    [46, 65],
#    [46, 66],
#    [48, 67],
#    [48, 68],
#    [50, 69],
#    [50, 70],
#    [54, 71],
#    [54, 72],
#    [54, 73],
#    [54, 74],
#    [54, 75],
#    [56, 76],
#    [56, 77],
#    [56, 78],
#    [57, 79],
#    [57, 80],
#    [57, 81],
#    [61, 82],
#    [61, 83],
#    [61, 84],
#    [61, 85],
#    [61, 86],
#    [63, 87],
#    [63, 88],
#    [63, 89],
#    [68, 90],
#    [68, 91],
#    [68, 92],
#    [69, 93],
#    [69, 94],
#    [69, 95],
#    [70, 96],
#    [70, 97],
#    [70, 98],
#    [71, 99],
#    [71, 100],
#    [73, 101],
#    [73, 102],
#    [73, 103],
#    [75, 104],
#    [75, 105],
#    [77, 106],
#    [77, 107],
#    [81, 108],
#    [81, 109],
#    [81, 110],
#    [81, 111],
#    [82, 112],
#    [82, 113],
#    [84, 114],
#    [84, 115],
#    [84, 116],
#    [86, 117],
#    [86, 118],
#    [88, 119],
#    [88, 120],
#    [92, 121],
#    [92, 122],
#    [98, 123],
#    [98, 124],
#    [100, 125],
#    [100, 126],
#    [100, 127],
#    [106, 128],
#    [106, 129],
#    [106, 130],
#    [113, 131],
#    [113, 132],
#    [113, 133],
#    [119, 134],
#    [119, 135],
#    [119, 136],
#    [122, 137],
#    [122, 138],
#    [124, 139],
#    [124, 140],
#    [128, 141],
#    [128, 142],
#    [128, 143],
#    [128, 144],
#    [130, 145],
#    [130, 146],
#    [130, 147],
#    [134, 148],
#    [134, 149],
#    [134, 150],
#    [136, 151],
#    [136, 152],
#    [136, 153],
#    [136, 154],
#    [138, 155],
#    [138, 156],
#    [138, 157],
#    [140, 158],
#    [140, 159],
#    [140, 160],
#    [147, 161],
#    [147, 162],
#    [147, 163],
#    [153, 164],
#    [153, 165],
#    [153, 166],
#    [153, 167],
#    [156, 168],
#    [156, 169],
#    [156, 170]]},
#  0]

# %%
trainset[0][0]['graph'].ndata['token']
# Out:
# tensor([113, 113, 113, 113, 112,  25, 113,  67,  25, 113,  67,  35, 113, 111,
#          69, 111,  69, 111, 111,  69, 111,  69, 111,   9, 111, 113,  63, 113,
#          64,  35,  38, 113,  48, 111, 113, 113,  61, 113,  62,  63, 113, 113,
#         113, 113, 113,  64, 113, 111, 113,  67, 113,  67,  21,  61, 113,  62,
#         113, 113,  67,  21,  61, 113,  62, 113, 111,  65,  66, 111, 113, 113,
#         113, 113,  67, 113,  67, 113,  63, 113,  64, 111,  69, 113, 113,  67,
#         113,  67, 113,  63, 113,  64, 111,  70, 113,  27,  65,  66, 111,  70,
#         113,  27, 113, 111,  72,  51, 111,  83, 113,  67, 111,  61, 111,  62,
#          27, 113, 111,  79,  51, 111,  84, 113,  67,  31, 113,  31, 113, 111,
#          70,  51, 113,  70, 113, 111,  70,  51, 113,  69, 113, 111, 113,  27,
#         113, 111,  65, 111,  66, 111,  69, 113, 111,  69, 111, 111,  61, 113,
#          62,  61, 113,  62,  65,  51,  66, 111,  61,  62, 111,  65, 111,  66,
#         111,  69, 111])

# %%
trainset[0][0]['edge']
# Out:
# [[0, 1],
#  [0, 2],
#  [0, 3],
#  [0, 4],
#  [1, 5],
#  [1, 6],
#  [1, 7],
#  [2, 8],
#  [2, 9],
#  [2, 10],
#  [3, 11],
#  [3, 12],
#  [6, 13],
#  [6, 14],
#  [6, 15],
#  [6, 16],
#  [6, 17],
#  [9, 18],
#  [9, 19],
#  [9, 20],
#  [9, 21],
#  [9, 22],
#  [12, 23],
#  [12, 24],
#  [12, 25],
#  [25, 26],
#  [25, 27],
#  [25, 28],
#  [27, 29],
#  [27, 30],
#  [27, 31],
#  [31, 32],
#  [31, 33],
#  [31, 34],
#  [31, 35],
#  [34, 36],
#  [34, 37],
#  [34, 38],
#  [35, 39],
#  [35, 40],
#  [35, 41],
#  [35, 42],
#  [35, 43],
#  [35, 44],
#  [35, 45],
#  [37, 46],
#  [37, 47],
#  [40, 48],
#  [40, 49],
#  [41, 50],
#  [41, 51],
#  [42, 52],
#  [42, 53],
#  [42, 54],
#  [42, 55],
#  [42, 56],
#  [43, 57],
#  [43, 58],
#  [44, 59],
#  [44, 60],
#  [44, 61],
#  [44, 62],
#  [44, 63],
#  [46, 64],
#  [46, 65],
#  [46, 66],
#  [48, 67],
#  [48, 68],
#  [50, 69],
#  [50, 70],
#  [54, 71],
#  [54, 72],
#  [54, 73],
#  [54, 74],
#  [54, 75],
#  [56, 76],
#  [56, 77],
#  [56, 78],
#  [57, 79],
#  [57, 80],
#  [57, 81],
#  [61, 82],
#  [61, 83],
#  [61, 84],
#  [61, 85],
#  [61, 86],
#  [63, 87],
#  [63, 88],
#  [63, 89],
#  [68, 90],
#  [68, 91],
#  [68, 92],
#  [69, 93],
#  [69, 94],
#  [69, 95],
#  [70, 96],
#  [70, 97],
#  [70, 98],
#  [71, 99],
#  [71, 100],
#  [73, 101],
#  [73, 102],
#  [73, 103],
#  [75, 104],
#  [75, 105],
#  [77, 106],
#  [77, 107],
#  [81, 108],
#  [81, 109],
#  [81, 110],
#  [81, 111],
#  [82, 112],
#  [82, 113],
#  [84, 114],
#  [84, 115],
#  [84, 116],
#  [86, 117],
#  [86, 118],
#  [88, 119],
#  [88, 120],
#  [92, 121],
#  [92, 122],
#  [98, 123],
#  [98, 124],
#  [100, 125],
#  [100, 126],
#  [100, 127],
#  [106, 128],
#  [106, 129],
#  [106, 130],
#  [113, 131],
#  [113, 132],
#  [113, 133],
#  [119, 134],
#  [119, 135],
#  [119, 136],
#  [122, 137],
#  [122, 138],
#  [124, 139],
#  [124, 140],
#  [128, 141],
#  [128, 142],
#  [128, 143],
#  [128, 144],
#  [130, 145],
#  [130, 146],
#  [130, 147],
#  [134, 148],
#  [134, 149],
#  [134, 150],
#  [136, 151],
#  [136, 152],
#  [136, 153],
#  [136, 154],
#  [138, 155],
#  [138, 156],
#  [138, 157],
#  [140, 158],
#  [140, 159],
#  [140, 160],
#  [147, 161],
#  [147, 162],
#  [147, 163],
#  [153, 164],
#  [153, 165],
#  [153, 166],
#  [153, 167],
#  [156, 168],
#  [156, 169],
#  [156, 170]]

# %%
token_vocabsize
# Out:
# 115

# %%
def graph2tree(edge, token_tensor, type_tensor, depth_tensor, dfs_tensor):
    root = []
    children_dict = {}
    for e in edge:
        if e[0] in children_dict:
            children_dict[e[0]].append(e[1])
        else:
            children_dict[e[0]] = []
            children_dict[e[0]].append(e[1])
    
    def addNode(tree, this_id):
        tree.append({})
        this_token = token_tensor[this_id]
        this_type = type_tensor[this_id]
        this_depth = depth_tensor[this_id]
        this_dfs = dfs_tensor[this_id]
        
        tree[-1]['node'] = this_token
        tree[-1]['type'] = this_type
        tree[-1]['depth'] = this_depth
        tree[-1]['dfs'] = this_dfs
        tree[-1]['children'] = []
        
        if this_id not in children_dict:
            return
        for e in children_dict[this_id]:
            addNode(tree[-1]['children'], e)
    
    addNode(root, 0)
    
    return root

def getTree(data):
    edge = data[0]['edge']
    token_tensor = data[0]['graph'].ndata['token'].tolist()
    type_tensor = data[0]['graph'].ndata['type'].tolist()
    depth_tensor = data[0]['graph'].ndata['depth'].tolist()
    dfs_tensor = data[0]['graph'].ndata['dfs'].tolist()
    return graph2tree(edge, token_tensor, type_tensor, depth_tensor, dfs_tensor)

# %%
t = getTree(trainset[0])[0]

# %%
trainset[0][1]
# Out:
# 0

# %%
all_children_num = []
def num_children(tree):
    all_children_num.append(len(tree['children']))
    for e in tree['children']:
        num_children(e)
num_children(t)

# %%
set(all_children_num)
# Out:
# {0, 2, 3, 4, 5, 7}

# %%
from tqdm.notebook import tqdm

# %%
def dataset_convert(dataset):
    output_dataset = []
    labels = []
    for e in tqdm(dataset):
        t = getTree(e)[0]
        l = str(e[1] + 1)
        d = {'tree':t, 'label':l}
        labels.append(l)
        output_dataset.append(d)
    return output_dataset, list(set(labels))

# %% [markdown]
# 做数据集

# %%
trees, labels = dataset_convert(devset)
data = (trees, labels)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=15000.0), HTML(value='')))

# %%
len(trees)
# Out:
# 15000

# %%
len(labels)
# Out:
# 250

# %%
save_path = '/home/zhangkechi/workspace/treecaps-master/codenet_data/Project_CodeNet_Java250_spts/dev.pkl'
import pickle
with open(save_path, 'wb') as file_handler:
    pickle.dump(data, file_handler, protocol=pickle.HIGHEST_PROTOCOL)

# %%
trees[0]
# Out:
# {'tree': {'node': 113,
#   'type': 0,
#   'depth': 0,
#   'dfs': 0,
#   'children': [{'node': 113,
#     'type': 2,
#     'depth': 1,
#     'dfs': 1,
#     'children': [{'node': 25,
#       'type': 105,
#       'depth': 2,
#       'dfs': 2,
#       'children': []},
#      {'node': 113,
#       'type': 46,
#       'depth': 2,
#       'dfs': 3,
#       'children': [{'node': 111,
#         'type': 105,
#         'depth': 3,
#         'dfs': 4,
#         'children': []},
#        {'node': 69, 'type': 105, 'depth': 3, 'dfs': 5, 'children': []},
#        {'node': 111, 'type': 105, 'depth': 3, 'dfs': 6, 'children': []},
#        {'node': 69, 'type': 105, 'depth': 3, 'dfs': 7, 'children': []},
#        {'node': 111, 'type': 105, 'depth': 3, 'dfs': 8, 'children': []}]},
#      {'node': 67, 'type': 105, 'depth': 2, 'dfs': 9, 'children': []}]},
#    {'node': 113,
#     'type': 2,
#     'depth': 1,
#     'dfs': 10,
#     'children': [{'node': 25,
#       'type': 105,
#       'depth': 2,
#       'dfs': 11,
#       'children': []},
#      {'node': 113,
#       'type': 46,
#       'depth': 2,
#       'dfs': 12,
#       'children': [{'node': 111,
#         'type': 105,
#         'depth': 3,
#         'dfs': 13,
#         'children': []},
#        {'node': 69, 'type': 105, 'depth': 3, 'dfs': 14, 'children': []},
#        {'node': 111, 'type': 105, 'depth': 3, 'dfs': 15, 'children': []},
#        {'node': 69, 'type': 105, 'depth': 3, 'dfs': 16, 'children': []},
#        {'node': 111, 'type': 105, 'depth': 3, 'dfs': 17, 'children': []}]},
#      {'node': 67, 'type': 105, 'depth': 2, 'dfs': 18, 'children': []}]},
#    {'node': 113,
#     'type': 2,
#     'depth': 1,
#     'dfs': 19,
#     'children': [{'node': 25,
#       'type': 105,
#       'depth': 2,
#       'dfs': 20,
#       'children': []},
#      {'node': 113,
#       'type': 46,
#       'depth': 2,
#       'dfs': 21,
#       'children': [{'node': 111,
#         'type': 105,
#         'depth': 3,
#         'dfs': 22,
#         'children': []},
#        {'node': 69, 'type': 105, 'depth': 3, 'dfs': 23, 'children': []},
#        {'node': 111, 'type': 105, 'depth': 3, 'dfs': 24, 'children': []},
#        {'node': 69, 'type': 105, 'depth': 3, 'dfs': 25, 'children': []},
#        {'node': 111, 'type': 105, 'depth': 3, 'dfs': 26, 'children': []}]},
#      {'node': 67, 'type': 105, 'depth': 2, 'dfs': 27, 'children': []}]},
#    {'node': 113,
#     'type': 2,
#     'depth': 1,
#     'dfs': 28,
#     'children': [{'node': 25,
#       'type': 105,
#       'depth': 2,
#       'dfs': 29,
#       'children': []},
#      {'node': 113,
#       'type': 46,
#       'depth': 2,
#       'dfs': 30,
#       'children': [{'node': 111,
#         'type': 105,
#         'depth': 3,
#         'dfs': 31,
#         'children': []},
#        {'node': 69, 'type': 105, 'depth': 3, 'dfs': 32, 'children': []},
#        {'node': 111, 'type': 105, 'depth': 3, 'dfs': 33, 'children': []},
#        {'node': 69, 'type': 105, 'depth': 3, 'dfs': 34, 'children': []},
#        {'node': 111, 'type': 105, 'depth': 3, 'dfs': 35, 'children': []}]},
#      {'node': 67, 'type': 105, 'depth': 2, 'dfs': 36, 'children': []}]},
#    {'node': 113,
#     'type': 7,
#     'depth': 1,
#     'dfs': 37,
#     'children': [{'node': 9,
#       'type': 105,
#       'depth': 2,
#       'dfs': 38,
#       'children': []},
#      {'node': 111, 'type': 105, 'depth': 2, 'dfs': 39, 'children': []},
#      {'node': 113,
#       'type': 16,
#       'depth': 2,
#       'dfs': 40,
#       'children': [{'node': 63,
#         'type': 105,
#         'depth': 3,
#         'dfs': 41,
#         'children': []},
#        {'node': 113,
#         'type': 18,
#         'depth': 3,
#         'dfs': 42,
#         'children': [{'node': 38,
#           'type': 105,
#           'depth': 4,
#           'dfs': 43,
#           'children': []},
#          {'node': 113,
#           'type': 26,
#           'depth': 4,
#           'dfs': 44,
#           'children': [{'node': 113,
#             'type': 39,
#             'depth': 5,
#             'dfs': 45,
#             'children': [{'node': 111,
#               'type': 105,
#               'depth': 6,
#               'dfs': 46,
#               'children': []},
#              {'node': 113,
#               'type': 101,
#               'depth': 6,
#               'dfs': 47,
#               'children': [{'node': 72,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 48,
#                 'children': []},
#                {'node': 111,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 49,
#                 'children': []},
#                {'node': 71,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 50,
#                 'children': []}]}]},
#            {'node': 113,
#             'type': 35,
#             'depth': 5,
#             'dfs': 51,
#             'children': [{'node': 111,
#               'type': 105,
#               'depth': 6,
#               'dfs': 52,
#               'children': []},
#              {'node': 70, 'type': 105, 'depth': 6, 'dfs': 53, 'children': []},
#              {'node': 113,
#               'type': 83,
#               'depth': 6,
#               'dfs': 54,
#               'children': [{'node': 31,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 55,
#                 'children': []},
#                {'node': 113,
#                 'type': 89,
#                 'depth': 7,
#                 'dfs': 56,
#                 'children': [{'node': 113,
#                   'type': 90,
#                   'depth': 8,
#                   'dfs': 57,
#                   'children': [{'node': 111,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 58,
#                     'children': []},
#                    {'node': 113,
#                     'type': 101,
#                     'depth': 9,
#                     'dfs': 59,
#                     'children': [{'node': 72,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 60,
#                       'children': []},
#                      {'node': 111,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 61,
#                       'children': []},
#                      {'node': 71,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 62,
#                       'children': []}]}]},
#                  {'node': 113,
#                   'type': 104,
#                   'depth': 8,
#                   'dfs': 63,
#                   'children': [{'node': 61,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 64,
#                     'children': []},
#                    {'node': 62,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 65,
#                     'children': []}]}]}]}]},
#            {'node': 67,
#             'type': 105,
#             'depth': 5,
#             'dfs': 66,
#             'children': []}]}]},
#        {'node': 113,
#         'type': 18,
#         'depth': 3,
#         'dfs': 67,
#         'children': [{'node': 35,
#           'type': 105,
#           'depth': 4,
#           'dfs': 68,
#           'children': []},
#          {'node': 38, 'type': 105, 'depth': 4, 'dfs': 69, 'children': []},
#          {'node': 113,
#           'type': 20,
#           'depth': 4,
#           'dfs': 70,
#           'children': [{'node': 48,
#             'type': 105,
#             'depth': 5,
#             'dfs': 71,
#             'children': []},
#            {'node': 111, 'type': 105, 'depth': 5, 'dfs': 72, 'children': []},
#            {'node': 113,
#             'type': 42,
#             'depth': 5,
#             'dfs': 73,
#             'children': [{'node': 61,
#               'type': 105,
#               'depth': 6,
#               'dfs': 74,
#               'children': []},
#              {'node': 113,
#               'type': 44,
#               'depth': 6,
#               'dfs': 75,
#               'children': [{'node': 113,
#                 'type': 99,
#                 'depth': 7,
#                 'dfs': 76,
#                 'children': [{'node': 111,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 77,
#                   'children': []},
#                  {'node': 65,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 78,
#                   'children': []},
#                  {'node': 66,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 79,
#                   'children': []}]},
#                {'node': 111,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 80,
#                 'children': []}]},
#              {'node': 62,
#               'type': 105,
#               'depth': 6,
#               'dfs': 81,
#               'children': []}]},
#            {'node': 113,
#             'type': 64,
#             'depth': 5,
#             'dfs': 82,
#             'children': [{'node': 63,
#               'type': 105,
#               'depth': 6,
#               'dfs': 83,
#               'children': []},
#              {'node': 113,
#               'type': 68,
#               'depth': 6,
#               'dfs': 84,
#               'children': [{'node': 113,
#                 'type': 83,
#                 'depth': 7,
#                 'dfs': 85,
#                 'children': [{'node': 111,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 86,
#                   'children': []},
#                  {'node': 69,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 87,
#                   'children': []},
#                  {'node': 113,
#                   'type': 82,
#                   'depth': 8,
#                   'dfs': 88,
#                   'children': [{'node': 111,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 89,
#                     'children': []},
#                    {'node': 61,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 90,
#                     'children': []},
#                    {'node': 113,
#                     'type': 81,
#                     'depth': 9,
#                     'dfs': 91,
#                     'children': [{'node': 111,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 92,
#                       'children': []},
#                      {'node': 68,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 93,
#                       'children': []},
#                      {'node': 51,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 94,
#                       'children': []},
#                      {'node': 68,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 95,
#                       'children': []},
#                      {'node': 51,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 96,
#                       'children': []},
#                      {'node': 68,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 97,
#                       'children': []},
#                      {'node': 51,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 98,
#                       'children': []}]},
#                    {'node': 62,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 99,
#                     'children': []}]}]},
#                {'node': 67,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 100,
#                 'children': []}]},
#              {'node': 113,
#               'type': 65,
#               'depth': 6,
#               'dfs': 101,
#               'children': [{'node': 113,
#                 'type': 66,
#                 'depth': 7,
#                 'dfs': 102,
#                 'children': [{'node': 111,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 103,
#                   'children': []},
#                  {'node': 113,
#                   'type': 35,
#                   'depth': 8,
#                   'dfs': 104,
#                   'children': [{'node': 111,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 105,
#                     'children': []},
#                    {'node': 70,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 106,
#                     'children': []},
#                    {'node': 113,
#                     'type': 83,
#                     'depth': 9,
#                     'dfs': 107,
#                     'children': [{'node': 31,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 108,
#                       'children': []},
#                      {'node': 113,
#                       'type': 89,
#                       'depth': 10,
#                       'dfs': 109,
#                       'children': [{'node': 111,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 110,
#                         'children': []},
#                        {'node': 113,
#                         'type': 104,
#                         'depth': 11,
#                         'dfs': 111,
#                         'children': [{'node': 61,
#                           'type': 105,
#                           'depth': 12,
#                           'dfs': 112,
#                           'children': []},
#                          {'node': 113,
#                           'type': 83,
#                           'depth': 12,
#                           'dfs': 113,
#                           'children': [{'node': 111,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 114,
#                             'children': []},
#                            {'node': 69,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 115,
#                             'children': []},
#                            {'node': 111,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 116,
#                             'children': []}]},
#                          {'node': 62,
#                           'type': 105,
#                           'depth': 12,
#                           'dfs': 117,
#                           'children': []}]}]}]}]}]},
#                {'node': 67,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 118,
#                 'children': []}]},
#              {'node': 113,
#               'type': 68,
#               'depth': 6,
#               'dfs': 119,
#               'children': [{'node': 21,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 120,
#                 'children': []},
#                {'node': 61,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 121,
#                 'children': []},
#                {'node': 113,
#                 'type': 77,
#                 'depth': 7,
#                 'dfs': 122,
#                 'children': [{'node': 113,
#                   'type': 66,
#                   'depth': 8,
#                   'dfs': 123,
#                   'children': [{'node': 27,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 124,
#                     'children': []},
#                    {'node': 113,
#                     'type': 35,
#                     'depth': 9,
#                     'dfs': 125,
#                     'children': [{'node': 111,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 126,
#                       'children': []},
#                      {'node': 70,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 127,
#                       'children': []},
#                      {'node': 51,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 128,
#                       'children': []}]}]},
#                  {'node': 67,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 129,
#                   'children': []},
#                  {'node': 113,
#                   'type': 83,
#                   'depth': 8,
#                   'dfs': 130,
#                   'children': [{'node': 111,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 131,
#                     'children': []},
#                    {'node': 72,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 132,
#                     'children': []},
#                    {'node': 51,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 133,
#                     'children': []}]},
#                  {'node': 67,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 134,
#                   'children': []},
#                  {'node': 113,
#                   'type': 83,
#                   'depth': 8,
#                   'dfs': 135,
#                   'children': [{'node': 111,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 136,
#                     'children': []},
#                    {'node': 83,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 137,
#                     'children': []}]}]},
#                {'node': 62,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 138,
#                 'children': []},
#                {'node': 113,
#                 'type': 64,
#                 'depth': 7,
#                 'dfs': 139,
#                 'children': [{'node': 63,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 140,
#                   'children': []},
#                  {'node': 113,
#                   'type': 65,
#                   'depth': 8,
#                   'dfs': 141,
#                   'children': [{'node': 113,
#                     'type': 66,
#                     'depth': 9,
#                     'dfs': 142,
#                     'children': [{'node': 27,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 143,
#                       'children': []},
#                      {'node': 113,
#                       'type': 35,
#                       'depth': 10,
#                       'dfs': 144,
#                       'children': [{'node': 111,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 145,
#                         'children': []},
#                        {'node': 70,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 146,
#                         'children': []},
#                        {'node': 113,
#                         'type': 83,
#                         'depth': 11,
#                         'dfs': 147,
#                         'children': [{'node': 111,
#                           'type': 105,
#                           'depth': 12,
#                           'dfs': 148,
#                           'children': []},
#                          {'node': 69,
#                           'type': 105,
#                           'depth': 12,
#                           'dfs': 149,
#                           'children': []},
#                          {'node': 113,
#                           'type': 82,
#                           'depth': 12,
#                           'dfs': 150,
#                           'children': [{'node': 111,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 151,
#                             'children': []},
#                            {'node': 61,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 152,
#                             'children': []},
#                            {'node': 62,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 153,
#                             'children': []}]}]}]}]},
#                    {'node': 67,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 154,
#                     'children': []}]},
#                  {'node': 113,
#                   'type': 68,
#                   'depth': 8,
#                   'dfs': 155,
#                   'children': [{'node': 113,
#                     'type': 82,
#                     'depth': 9,
#                     'dfs': 156,
#                     'children': [{'node': 111,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 157,
#                       'children': []},
#                      {'node': 61,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 158,
#                       'children': []},
#                      {'node': 111,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 159,
#                       'children': []},
#                      {'node': 62,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 160,
#                       'children': []}]},
#                    {'node': 67,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 161,
#                     'children': []}]},
#                  {'node': 64,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 162,
#                   'children': []}]}]},
#              {'node': 113,
#               'type': 68,
#               'depth': 6,
#               'dfs': 163,
#               'children': [{'node': 21,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 164,
#                 'children': []},
#                {'node': 61,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 165,
#                 'children': []},
#                {'node': 113,
#                 'type': 77,
#                 'depth': 7,
#                 'dfs': 166,
#                 'children': [{'node': 113,
#                   'type': 66,
#                   'depth': 8,
#                   'dfs': 167,
#                   'children': [{'node': 27,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 168,
#                     'children': []},
#                    {'node': 113,
#                     'type': 35,
#                     'depth': 9,
#                     'dfs': 169,
#                     'children': [{'node': 111,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 170,
#                       'children': []},
#                      {'node': 70,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 171,
#                       'children': []},
#                      {'node': 51,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 172,
#                       'children': []}]}]},
#                  {'node': 67,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 173,
#                   'children': []},
#                  {'node': 113,
#                   'type': 83,
#                   'depth': 8,
#                   'dfs': 174,
#                   'children': [{'node': 111,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 175,
#                     'children': []},
#                    {'node': 72,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 176,
#                     'children': []},
#                    {'node': 113,
#                     'type': 83,
#                     'depth': 9,
#                     'dfs': 177,
#                     'children': [{'node': 111,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 178,
#                       'children': []},
#                      {'node': 69,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 179,
#                       'children': []},
#                      {'node': 113,
#                       'type': 82,
#                       'depth': 10,
#                       'dfs': 180,
#                       'children': [{'node': 111,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 181,
#                         'children': []},
#                        {'node': 61,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 182,
#                         'children': []},
#                        {'node': 62,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 183,
#                         'children': []}]}]}]},
#                  {'node': 67,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 184,
#                   'children': []},
#                  {'node': 113,
#                   'type': 83,
#                   'depth': 8,
#                   'dfs': 185,
#                   'children': [{'node': 111,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 186,
#                     'children': []},
#                    {'node': 83,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 187,
#                     'children': []}]}]},
#                {'node': 62,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 188,
#                 'children': []},
#                {'node': 113,
#                 'type': 64,
#                 'depth': 7,
#                 'dfs': 189,
#                 'children': [{'node': 63,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 190,
#                   'children': []},
#                  {'node': 113,
#                   'type': 68,
#                   'depth': 8,
#                   'dfs': 191,
#                   'children': [{'node': 113,
#                     'type': 83,
#                     'depth': 9,
#                     'dfs': 192,
#                     'children': [{'node': 113,
#                       'type': 83,
#                       'depth': 10,
#                       'dfs': 193,
#                       'children': [{'node': 111,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 194,
#                         'children': []},
#                        {'node': 69,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 195,
#                         'children': []},
#                        {'node': 111,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 196,
#                         'children': []}]},
#                      {'node': 69,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 197,
#                       'children': []},
#                      {'node': 113,
#                       'type': 82,
#                       'depth': 10,
#                       'dfs': 198,
#                       'children': [{'node': 111,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 199,
#                         'children': []},
#                        {'node': 61,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 200,
#                         'children': []},
#                        {'node': 113,
#                         'type': 83,
#                         'depth': 11,
#                         'dfs': 201,
#                         'children': [{'node': 111,
#                           'type': 105,
#                           'depth': 12,
#                           'dfs': 202,
#                           'children': []},
#                          {'node': 69,
#                           'type': 105,
#                           'depth': 12,
#                           'dfs': 203,
#                           'children': []},
#                          {'node': 113,
#                           'type': 82,
#                           'depth': 12,
#                           'dfs': 204,
#                           'children': [{'node': 111,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 205,
#                             'children': []},
#                            {'node': 61,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 206,
#                             'children': []},
#                            {'node': 111,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 207,
#                             'children': []},
#                            {'node': 62,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 208,
#                             'children': []}]}]},
#                        {'node': 62,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 209,
#                         'children': []}]}]},
#                    {'node': 67,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 210,
#                     'children': []}]},
#                  {'node': 64,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 211,
#                   'children': []}]}]},
#              {'node': 64,
#               'type': 105,
#               'depth': 6,
#               'dfs': 212,
#               'children': []}]}]}]},
#        {'node': 113,
#         'type': 18,
#         'depth': 3,
#         'dfs': 213,
#         'children': [{'node': 35,
#           'type': 105,
#           'depth': 4,
#           'dfs': 214,
#           'children': []},
#          {'node': 38, 'type': 105, 'depth': 4, 'dfs': 215, 'children': []},
#          {'node': 113,
#           'type': 20,
#           'depth': 4,
#           'dfs': 216,
#           'children': [{'node': 48,
#             'type': 105,
#             'depth': 5,
#             'dfs': 217,
#             'children': []},
#            {'node': 111, 'type': 105, 'depth': 5, 'dfs': 218, 'children': []},
#            {'node': 113,
#             'type': 42,
#             'depth': 5,
#             'dfs': 219,
#             'children': [{'node': 61,
#               'type': 105,
#               'depth': 6,
#               'dfs': 220,
#               'children': []},
#              {'node': 113,
#               'type': 44,
#               'depth': 6,
#               'dfs': 221,
#               'children': [{'node': 27,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 222,
#                 'children': []},
#                {'node': 111,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 223,
#                 'children': []}]},
#              {'node': 62,
#               'type': 105,
#               'depth': 6,
#               'dfs': 224,
#               'children': []}]},
#            {'node': 113,
#             'type': 64,
#             'depth': 5,
#             'dfs': 225,
#             'children': [{'node': 63,
#               'type': 105,
#               'depth': 6,
#               'dfs': 226,
#               'children': []},
#              {'node': 113,
#               'type': 68,
#               'depth': 6,
#               'dfs': 227,
#               'children': [{'node': 21,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 228,
#                 'children': []},
#                {'node': 61,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 229,
#                 'children': []},
#                {'node': 113,
#                 'type': 77,
#                 'depth': 7,
#                 'dfs': 230,
#                 'children': [{'node': 113,
#                   'type': 66,
#                   'depth': 8,
#                   'dfs': 231,
#                   'children': [{'node': 27,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 232,
#                     'children': []},
#                    {'node': 113,
#                     'type': 35,
#                     'depth': 9,
#                     'dfs': 233,
#                     'children': [{'node': 111,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 234,
#                       'children': []},
#                      {'node': 70,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 235,
#                       'children': []},
#                      {'node': 51,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 236,
#                       'children': []}]}]},
#                  {'node': 67,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 237,
#                   'children': []},
#                  {'node': 113,
#                   'type': 83,
#                   'depth': 8,
#                   'dfs': 238,
#                   'children': [{'node': 111,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 239,
#                     'children': []},
#                    {'node': 72,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 240,
#                     'children': []},
#                    {'node': 113,
#                     'type': 83,
#                     'depth': 9,
#                     'dfs': 241,
#                     'children': [{'node': 111,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 242,
#                       'children': []},
#                      {'node': 69,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 243,
#                       'children': []},
#                      {'node': 113,
#                       'type': 82,
#                       'depth': 10,
#                       'dfs': 244,
#                       'children': [{'node': 111,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 245,
#                         'children': []},
#                        {'node': 61,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 246,
#                         'children': []},
#                        {'node': 62,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 247,
#                         'children': []}]}]}]},
#                  {'node': 67,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 248,
#                   'children': []},
#                  {'node': 113,
#                   'type': 83,
#                   'depth': 8,
#                   'dfs': 249,
#                   'children': [{'node': 111,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 250,
#                     'children': []},
#                    {'node': 83,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 251,
#                     'children': []}]}]},
#                {'node': 62,
#                 'type': 105,
#                 'depth': 7,
#                 'dfs': 252,
#                 'children': []},
#                {'node': 113,
#                 'type': 64,
#                 'depth': 7,
#                 'dfs': 253,
#                 'children': [{'node': 63,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 254,
#                   'children': []},
#                  {'node': 113,
#                   'type': 68,
#                   'depth': 8,
#                   'dfs': 255,
#                   'children': [{'node': 22,
#                     'type': 105,
#                     'depth': 9,
#                     'dfs': 256,
#                     'children': []},
#                    {'node': 113,
#                     'type': 80,
#                     'depth': 9,
#                     'dfs': 257,
#                     'children': [{'node': 61,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 258,
#                       'children': []},
#                      {'node': 113,
#                       'type': 83,
#                       'depth': 10,
#                       'dfs': 259,
#                       'children': [{'node': 113,
#                         'type': 83,
#                         'depth': 11,
#                         'dfs': 260,
#                         'children': [{'node': 111,
#                           'type': 105,
#                           'depth': 12,
#                           'dfs': 261,
#                           'children': []},
#                          {'node': 69,
#                           'type': 105,
#                           'depth': 12,
#                           'dfs': 262,
#                           'children': []},
#                          {'node': 113,
#                           'type': 82,
#                           'depth': 12,
#                           'dfs': 263,
#                           'children': [{'node': 111,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 264,
#                             'children': []},
#                            {'node': 61,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 265,
#                             'children': []},
#                            {'node': 111,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 266,
#                             'children': []},
#                            {'node': 62,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 267,
#                             'children': []}]}]},
#                        {'node': 78,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 268,
#                         'children': []},
#                        {'node': 111,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 269,
#                         'children': []}]},
#                      {'node': 62,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 270,
#                       'children': []}]},
#                    {'node': 113,
#                     'type': 64,
#                     'depth': 9,
#                     'dfs': 271,
#                     'children': [{'node': 63,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 272,
#                       'children': []},
#                      {'node': 113,
#                       'type': 68,
#                       'depth': 10,
#                       'dfs': 273,
#                       'children': [{'node': 113,
#                         'type': 83,
#                         'depth': 11,
#                         'dfs': 274,
#                         'children': [{'node': 111,
#                           'type': 105,
#                           'depth': 12,
#                           'dfs': 275,
#                           'children': []},
#                          {'node': 69,
#                           'type': 105,
#                           'depth': 12,
#                           'dfs': 276,
#                           'children': []},
#                          {'node': 113,
#                           'type': 82,
#                           'depth': 12,
#                           'dfs': 277,
#                           'children': [{'node': 111,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 278,
#                             'children': []},
#                            {'node': 61,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 279,
#                             'children': []},
#                            {'node': 51,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 280,
#                             'children': []},
#                            {'node': 62,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 281,
#                             'children': []}]}]},
#                        {'node': 67,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 282,
#                         'children': []}]},
#                      {'node': 113,
#                       'type': 68,
#                       'depth': 10,
#                       'dfs': 283,
#                       'children': [{'node': 113,
#                         'type': 83,
#                         'depth': 11,
#                         'dfs': 284,
#                         'children': [{'node': 111,
#                           'type': 105,
#                           'depth': 12,
#                           'dfs': 285,
#                           'children': []},
#                          {'node': 69,
#                           'type': 105,
#                           'depth': 12,
#                           'dfs': 286,
#                           'children': []},
#                          {'node': 113,
#                           'type': 82,
#                           'depth': 12,
#                           'dfs': 287,
#                           'children': [{'node': 111,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 288,
#                             'children': []},
#                            {'node': 61,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 289,
#                             'children': []},
#                            {'node': 113,
#                             'type': 81,
#                             'depth': 13,
#                             'dfs': 290,
#                             'children': [{'node': 111,
#                               'type': 105,
#                               'depth': 14,
#                               'dfs': 291,
#                               'children': []},
#                              {'node': 68,
#                               'type': 105,
#                               'depth': 14,
#                               'dfs': 292,
#                               'children': []},
#                              {'node': 111,
#                               'type': 105,
#                               'depth': 14,
#                               'dfs': 293,
#                               'children': []}]},
#                            {'node': 62,
#                             'type': 105,
#                             'depth': 13,
#                             'dfs': 294,
#                             'children': []}]}]},
#                        {'node': 67,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 295,
#                         'children': []}]},
#                      {'node': 113,
#                       'type': 68,
#                       'depth': 10,
#                       'dfs': 296,
#                       'children': [{'node': 4,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 297,
#                         'children': []},
#                        {'node': 67,
#                         'type': 105,
#                         'depth': 11,
#                         'dfs': 298,
#                         'children': []}]},
#                      {'node': 64,
#                       'type': 105,
#                       'depth': 10,
#                       'dfs': 299,
#                       'children': []}]}]},
#                  {'node': 64,
#                   'type': 105,
#                   'depth': 8,
#                   'dfs': 300,
#                   'children': []}]}]},
#              {'node': 64,
#               'type': 105,
#               'depth': 6,
#               'dfs': 301,
#               'children': []}]}]}]},
#        {'node': 64, 'type': 105, 'depth': 3, 'dfs': 302, 'children': []}]}]},
#    {'node': 112, 'type': 105, 'depth': 1, 'dfs': 303, 'children': []}]},
#  'label': '1'}
